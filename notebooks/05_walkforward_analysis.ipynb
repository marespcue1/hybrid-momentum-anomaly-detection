# %% [markdown]
# # Walk-Forward Analysis — Hybrid Momentum Strategy
#
# Este notebook importa `src/analysis/visualization.py` y genera las graficas
# de resultados Walk-Forward. No simula nada: carga los CSVs de `results/`.
#
# **Maquetacion academica**: Sin titulos superiores ni etiquetas flotantes.
#
# ```bash
# python run_pipeline.py --mode walkforward
# ```

# %%
import os, sys, warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

_NOTEBOOK_DIR = os.path.abspath('')
_ROOT = os.path.dirname(_NOTEBOOK_DIR)
_SRC  = os.path.join(_ROOT, 'src')
if _SRC not in sys.path:
    sys.path.insert(0, _SRC)

from config import (
    FILE_WF_RESULTS, FILE_GRID_RESULTS,
    FECHA_TRAIN_END, FECHA_TEST_START, FECHA_INICIO_ANALISIS, DIR_FIGURES,
)
os.makedirs(DIR_FIGURES, exist_ok=True)

from analysis.visualization import (
    reconstruct_daily_equity, plot_equity_curve_with_split,
    plot_sharpe_scatter, plot_hyperparameter_distribution,
    plot_degradation_bar, plot_oos_parameter_sensitivity,
    load_walk_forward_results, load_grid_results,
    _get_price_wide, _run_engine_for_config, _top10pct_by_sharpe_test,
)

plt.rcParams.update({
    'font.family': 'sans-serif', 'axes.grid': True,
    'grid.alpha': 0.3, 'grid.linestyle': '--',
    'axes.spines.top': False, 'axes.spines.right': False, 'figure.dpi': 120,
})
COLOR_TRAIN = '#1f4e79'
COLOR_TEST  = '#e05c00'
SPLIT_DATE  = pd.Timestamp(FECHA_TEST_START)
print(f'Train ends : {FECHA_TRAIN_END}')
print(f'Test starts: {FECHA_TEST_START}')
# Out:
# Train ends : 2025-07-13
# Test starts: 2025-07-14

# %%
df_wf   = load_walk_forward_results()
df_grid = load_grid_results()
if df_wf is not None and not df_wf.empty:
    cols = ['rank_train', 'Sharpe_Train', 'Sharpe_Test', 'Sharpe_Degradation_%']
    print(df_wf[[c for c in cols if c in df_wf.columns]].to_string(index=False))
else:
    print('AVISO: Ejecutar python run_pipeline.py --mode walkforward')
# Out:
#  Sharpe_Train  Sharpe_Test
#         1.275        0.397
#         1.275        0.397
#         1.275        0.397
#         1.275        0.119
#         1.275        0.119
#         1.275        0.119
#         1.275        0.397
#         1.275        0.119
#         1.247        0.001
#         1.247        0.001
#         1.247        0.001
#         1.247       -0.132
#         1.247       -0.132
#         1.247        0.001
#         1.247       -0.132
#         1.247       -0.132
#         1.218       -0.008
#         1.218        0.104
#         1.218        0.104
#         1.218        0.104
#         1.218       -0.008
#         1.218        0.104
#         1.218       -0.008
#         1.218       -0.008
#         1.206        0.119
#         1.206        0.119
#         1.206        0.119
#         1.206        0.119
#         1.205       -0.008
#         1.205       -0.008
#         1.205       -0.008
#         1.205       -0.008
#         1.194       -0.260
#         1.194       -0.116
#         1.194       -0.260
#         1.194       -0.116
#         1.194       -0.260
#         1.194       -0.116
#         1.194       -0.260
#         1.194       -0.116
#         1.185        0.119
#         1.185        0.119
#         1.185        0.119
#         1.185        0.119
#         1.175       -0.005
#         1.175       -0.008
#         1.175       -0.143
#         1.175       -0.005
#         1.175       -0.143
#         1.175       -0.008
#         1.175       -0.008
#         1.175       -0.008
#   [visualization] Guardado -> c:\Users\marce\Desktop\UNIR\TFM\Proyecto\git\hybrid-momentum-anomaly-detection\results\figures\wf_01_equity_curve_winner_daily.png

# %% [markdown]
# ## Grafica 2 — Scatter: Sharpe Train vs Sharpe Test

# %%
if df_wf is not None and not df_wf.empty:
    plot_sharpe_scatter(wf_df=df_wf, save=True, filename='wf_02_sharpe_scatter.png')
# Out:
#   [visualization] Guardado -> c:\Users\marce\Desktop\UNIR\TFM\Proyecto\git\hybrid-momentum-anomaly-detection\results\figures\wf_02_sharpe_scatter.png

# %% [markdown]
# ## Grafica 3 — Barras Sharpe Train vs Test por Configuracion

# %%
if df_wf is not None and not df_wf.empty:
    plot_degradation_bar(wf_df=df_wf, save=True, filename='wf_03_degradation_bar.png')
# Out:
# [visualization] Sección 6 — 636 configs válidas; mostrando top/bottom 15 por Sharpe_Train.
#   [visualization] Guardado -> c:\Users\marce\Desktop\UNIR\TFM\Proyecto\git\hybrid-momentum-anomaly-detection\results\figures\wf_03_degradation_bar.png

# %% [markdown]
# ## Grafica 4 — Distribucion de Hiperparametros (Top 10 % por Sharpe_Test)
#
# Solo las configuraciones con mayor Sharpe Out-of-Sample.

# %%
if df_wf is not None and not df_wf.empty:
    elite = _top10pct_by_sharpe_test(df_wf)
    print(f'Top 10 % por Sharpe_Test: {len(elite)} configuraciones')
    plot_hyperparameter_distribution(wf_df=df_wf, save=True,
        filename='wf_04_hyperparameter_distribution_oos.png')
# Out:
#   [_top10pct_by_sharpe_test] Umbral Sharpe_Test >= 0.6350: 84/640 estrategias retenidas.
# Top 10 % por Sharpe_Test: 84 configuraciones
#   [_top10pct_by_sharpe_IS] Umbral Sharpe >= 0.8240: 648/6400 estrategias retenidas.
# [visualization] Sección 5 — Top 10 % Grid IS por Sharpe (In-Sample): N=648
# [visualization] Sección 5 — Coherencia de conteos (n_elite=648):
#   [OK] top_n: conteos=648, NaN=0, total=648
#   [OK] rebalance_freq: conteos=648, NaN=0, total=648
#   [OK] anomaly_lookback_days: conteos=648, NaN=0, total=648
#   [OK] momentum_signal: conteos=648, NaN=0, total=648
#   [OK] active_cluster: conteos=648, NaN=0, total=648
#   [OK] rank_weighted: conteos=648, NaN=0, total=648
#   [OK] min_portfolio_size: conteos=648, NaN=0, total=648
#   -> Todos los parámetros son matemáticamente coherentes.

# %% [markdown]
# ## Grafica 5 — Distribucion de Sharpe del Grid Search completo

# %%
if df_grid is not None and not df_grid.empty and 'Sharpe' in df_grid.columns:
    sharpes = df_grid['Sharpe'].dropna()
    fig, ax = plt.subplots(figsize=(11, 5))
    ax.hist(sharpes, bins=40, color=COLOR_TRAIN, alpha=0.7, edgecolor='white',
            label=f'Todas las combinaciones (N={len(sharpes):,})')
    if df_wf is not None and 'Sharpe_Train' in df_wf.columns:
        for i, s in enumerate(df_wf['Sharpe_Train'].dropna()):
            ax.axvline(x=s, color=COLOR_TEST, lw=1.5, alpha=0.8,
                       label='Ganadores Walk-Forward' if i == 0 else '_nolegend_')
    ax.axvline(x=sharpes.median(), color='green', lw=1.5, ls=':',
               label=f'Mediana ({sharpes.median():.3f})')
    ax.axvline(x=1.0, color='gray', lw=1.2, ls='--', label='Sharpe = 1.0')
    ax.set_xlabel('Sharpe Anualizado (In-Sample)', fontsize=10)
    ax.set_ylabel('Frecuencia', fontsize=10)
    ax.legend(fontsize=9)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.tight_layout()
    out = os.path.join(DIR_FIGURES, 'wf_05_sharpe_distribution_grid.png')
    plt.savefig(out, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'Guardado: {out}')
# Out:
# Guardado: c:\Users\marce\Desktop\UNIR\TFM\Proyecto\git\hybrid-momentum-anomaly-detection\results\figures\wf_05_sharpe_distribution_grid.png

# %% [markdown]
# ## Grafica 6 — Sensibilidad OOS por Hiperparametro (Top 10 % Sharpe_Test)
#
# > Puede tardar 1-2 minutos.

# %%
if df_wf is not None and not df_wf.empty:
    plot_oos_parameter_sensitivity(wf_df=df_wf, save=True,
        filename='wf_06_oos_parameter_sensitivity_top10pct.png')
# Out:
# [visualization] Pool OOS para sensibilidad: 636 configuraciones
# [visualization] Reconstruyendo curvas diarias OOS...
#   [progreso] 0% (1/636)
#   [progreso] 10% (63/636)
#   [progreso] 20% (126/636)
#   [progreso] 30% (189/636)
#   [progreso] 40% (252/636)
#   [progreso] 50% (315/636)
#   [progreso] 59% (378/636)
#   [progreso] 69% (441/636)
#   [progreso] 79% (504/636)
#   [progreso] 89% (567/636)
#   [progreso] 99% (630/636)
#   [visualization] 636/636 curvas reconstruidas (0 fallidas).
#   [visualization] Guardado -> c:\Users\marce\Desktop\UNIR\TFM\Proyecto\git\hybrid-momentum-anomaly-detection\results\figures\wf_06_oos_parameter_sensitivity_top10pct.png

# %% [markdown]
# ## Tabla Resumen Walk-Forward

# %%
if df_wf is not None and not df_wf.empty:

    # =========================================================
    # RESUMEN GLOBAL
    # =========================================================

    print("=" * 70)
    print("RESUMEN WALK-FORWARD")
    print("=" * 70)

    print(f"Número de configuraciones: {len(df_wf)}")

    print(
        f"Sharpe Test medio: "
        f"{df_wf['Sharpe_Test'].mean():.3f}"
    )

    print(
        f"Sharpe Test máximo: "
        f"{df_wf['Sharpe_Test'].max():.3f}"
    )

    print(
        f"Sharpe Train medio: "
        f"{df_wf['Sharpe_Train'].mean():.3f}"
    )

    if 'Degradacion_Sharpe' in df_wf.columns:

        print(
            f"Degradación media: "
            f"{df_wf['Degradacion_Sharpe'].mean():+.3f}"
        )

    # =========================================================
    # TOP CONFIGS
    # =========================================================

    print("\n")
    print("=" * 70)
    print("TOP 10 CONFIGURACIONES OOS")
    print("=" * 70)

    cols_show = [
        'top_n',
        'rebalance_freq',
        'momentum_signal',
        'active_cluster',
        'Sharpe_Train',
        'Sharpe_Test',
        'Degradacion_Sharpe',
    ]

    top10 = (
        df_wf
        .sort_values(
            'Sharpe_Test',
            ascending=False
        )
        .head(10)
    )

    display(
        top10[cols_show]
        .style
        .format({
            'Sharpe_Train': '{:.3f}',
            'Sharpe_Test': '{:.3f}',
            'Degradacion_Sharpe': '{:+.3f}',
        })
        .background_gradient(
            subset=['Sharpe_Test'],
            cmap='RdYlGn'
        )
    )
# Out:
# ======================================================================
# RESUMEN WALK-FORWARD
# ======================================================================
# Número de configuraciones: 640
# Sharpe Test medio: 0.266
# Sharpe Test máximo: 2.433
# Sharpe Train medio: 0.947
# Degradación media: +0.682
#
#
# ======================================================================
# TOP 10 CONFIGURACIONES OOS
# ======================================================================
# <style type="text/css">
# #T_285ba_row0_col5, #T_285ba_row1_col5, #T_285ba_row2_col5, #T_285ba_row3_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_285ba_row4_col5, #T_285ba_row5_col5 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_285ba_row6_col5, #T_285ba_row7_col5, #T_285ba_row8_col5, #T_285ba_row9_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_285ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_285ba_level0_col0" class="col_heading level0 col0" >top_n</th>
#       <th id="T_285ba_level0_col1" class="col_heading level0 col1" >rebalance_freq</th>
#       <th id="T_285ba_level0_col2" class="col_heading level0 col2" >momentum_signal</th>
#       <th id="T_285ba_level0_col3" class="col_heading level0 col3" >active_cluster</th>
#       <th id="T_285ba_level0_col4" class="col_heading level0 col4" >Sharpe_Train</th>
#       <th id="T_285ba_level0_col5" class="col_heading level0 col5" >Sharpe_Test</th>
#       <th id="T_285ba_level0_col6" class="col_heading level0 col6" >Degradacion_Sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_285ba_level0_row0" class="row_heading level0 row0" >545</th>
#       <td id="T_285ba_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_285ba_row0_col1" class="data row0 col1" >M</td>
#       <td id="T_285ba_row0_col2" class="data row0 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_285ba_row0_col4" class="data row0 col4" >0.835</td>
#       <td id="T_285ba_row0_col5" class="data row0 col5" >2.433</td>
#       <td id="T_285ba_row0_col6" class="data row0 col6" >-1.598</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row1" class="row_heading level0 row1" >543</th>
#       <td id="T_285ba_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_285ba_row1_col1" class="data row1 col1" >M</td>
#       <td id="T_285ba_row1_col2" class="data row1 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_285ba_row1_col4" class="data row1 col4" >0.835</td>
#       <td id="T_285ba_row1_col5" class="data row1 col5" >2.433</td>
#       <td id="T_285ba_row1_col6" class="data row1 col6" >-1.598</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row2" class="row_heading level0 row2" >548</th>
#       <td id="T_285ba_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_285ba_row2_col1" class="data row2 col1" >M</td>
#       <td id="T_285ba_row2_col2" class="data row2 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_285ba_row2_col4" class="data row2 col4" >0.835</td>
#       <td id="T_285ba_row2_col5" class="data row2 col5" >2.433</td>
#       <td id="T_285ba_row2_col6" class="data row2 col6" >-1.598</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row3" class="row_heading level0 row3" >541</th>
#       <td id="T_285ba_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_285ba_row3_col1" class="data row3 col1" >M</td>
#       <td id="T_285ba_row3_col2" class="data row3 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_285ba_row3_col4" class="data row3 col4" >0.835</td>
#       <td id="T_285ba_row3_col5" class="data row3 col5" >2.433</td>
#       <td id="T_285ba_row3_col6" class="data row3 col6" >-1.598</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row4" class="row_heading level0 row4" >637</th>
#       <td id="T_285ba_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_285ba_row4_col1" class="data row4 col1" >M</td>
#       <td id="T_285ba_row4_col2" class="data row4 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_285ba_row4_col4" class="data row4 col4" >0.824</td>
#       <td id="T_285ba_row4_col5" class="data row4 col5" >2.365</td>
#       <td id="T_285ba_row4_col6" class="data row4 col6" >-1.541</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row5" class="row_heading level0 row5" >633</th>
#       <td id="T_285ba_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_285ba_row5_col1" class="data row5 col1" >M</td>
#       <td id="T_285ba_row5_col2" class="data row5 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_285ba_row5_col4" class="data row5 col4" >0.824</td>
#       <td id="T_285ba_row5_col5" class="data row5 col5" >2.365</td>
#       <td id="T_285ba_row5_col6" class="data row5 col6" >-1.541</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row6" class="row_heading level0 row6" >338</th>
#       <td id="T_285ba_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_285ba_row6_col1" class="data row6 col1" >M</td>
#       <td id="T_285ba_row6_col2" class="data row6 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_285ba_row6_col4" class="data row6 col4" >0.894</td>
#       <td id="T_285ba_row6_col5" class="data row6 col5" >2.344</td>
#       <td id="T_285ba_row6_col6" class="data row6 col6" >-1.450</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row7" class="row_heading level0 row7" >335</th>
#       <td id="T_285ba_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_285ba_row7_col1" class="data row7 col1" >M</td>
#       <td id="T_285ba_row7_col2" class="data row7 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_285ba_row7_col4" class="data row7 col4" >0.894</td>
#       <td id="T_285ba_row7_col5" class="data row7 col5" >2.344</td>
#       <td id="T_285ba_row7_col6" class="data row7 col6" >-1.450</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row8" class="row_heading level0 row8" >334</th>
#       <td id="T_285ba_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_285ba_row8_col1" class="data row8 col1" >M</td>
#       <td id="T_285ba_row8_col2" class="data row8 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_285ba_row8_col4" class="data row8 col4" >0.894</td>
#       <td id="T_285ba_row8_col5" class="data row8 col5" >2.344</td>
#       <td id="T_285ba_row8_col6" class="data row8 col6" >-1.450</td>
#     </tr>
#     <tr>
#       <th id="T_285ba_level0_row9" class="row_heading level0 row9" >332</th>
#       <td id="T_285ba_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_285ba_row9_col1" class="data row9 col1" >M</td>
#       <td id="T_285ba_row9_col2" class="data row9 col2" >ALR1M_Z</td>
#       <td id="T_285ba_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_285ba_row9_col4" class="data row9 col4" >0.894</td>
#       <td id="T_285ba_row9_col5" class="data row9 col5" >2.344</td>
#       <td id="T_285ba_row9_col6" class="data row9 col6" >-1.450</td>
#     </tr>
#   </tbody>
# </table>

# %%
if df_wf is not None and not df_wf.empty:
    print(df_wf.columns.tolist())
    summary_cols = ['rank_train','Sharpe_Train','Sharpe_Test', 'Degradacion_Sharpe',#'Sharpe_Degradation_%',
                    #'CAGR_Train_%','CAGR_Test_%','MaxDD_Train_%','MaxDD_Test_%']
                    'CAGR_Train (%)', 'CAGR_Test (%)', 'MaxDD_Train (%)', 'MaxDD_Test (%)']
    avail = [c for c in summary_cols if c in df_wf.columns]
    try:
        styled = (
            df_wf[avail].style
            .format({'Sharpe_Train':'{:.3f}','Sharpe_Test':'{:.3f}',
                     'Sharpe_Degradation_%':'{:+.1f}%','CAGR_Train_%':'{:.1f}%',
                     'CAGR_Test_%':'{:.1f}%','MaxDD_Train_%':'{:.1f}%',
                     'MaxDD_Test_%':'{:.1f}%'}, na_rep='N/A')
            .background_gradient(subset=['Sharpe_Test'], cmap='RdYlGn')
            .background_gradient(subset=['Degradacion_Sharpe'#'Sharpe_Degradation_%'
                                         ], cmap='RdYlGn_r')
        )
        display(styled)
    except Exception:
        print(df_wf[avail].to_string(index=False))
    if 'Sharpe_Test' in df_wf.columns:
        vt = df_wf['Sharpe_Test'].dropna()
        print(f'Sharpe Test: media={vt.mean():.3f} | max={vt.max():.3f}')
    if 'Degradacion_Sharpe' in df_wf.columns:
        vd = df_wf['Degradacion_Sharpe'#'Sharpe_Degradation_%'
                   ].dropna()
        print(f'Degradacion media: {vd.mean():+.1f}% | {(vd>0).sum()}/{len(vd)} configs mejoran')
# Out:
# ['rank_insample', 'top_n', 'rebalance_freq', 'anomaly_lookback_days', 'momentum_signal', 'active_cluster', 'rank_weighted', 'min_portfolio_size', 'Sharpe_Train', 'Sharpe_Test', 'Degradacion_Sharpe', 'CAGR_Train (%)', 'CAGR_Test (%)', 'MaxDD_Train (%)', 'MaxDD_Test (%)']
# <style type="text/css">
# #T_926be_row0_col1, #T_926be_row1_col1, #T_926be_row2_col1, #T_926be_row6_col1, #T_926be_row212_col1, #T_926be_row213_col1, #T_926be_row214_col1, #T_926be_row215_col1, #T_926be_row263_col2, #T_926be_row265_col2, #T_926be_row266_col2, #T_926be_row267_col2, #T_926be_row377_col2, #T_926be_row379_col2, #T_926be_row382_col2, #T_926be_row385_col2, #T_926be_row392_col1, #T_926be_row393_col1, #T_926be_row394_col1, #T_926be_row395_col1, #T_926be_row517_col2, #T_926be_row521_col2, #T_926be_row522_col2, #T_926be_row523_col2, #T_926be_row595_col1, #T_926be_row595_col2, #T_926be_row596_col1, #T_926be_row596_col2, #T_926be_row602_col1, #T_926be_row602_col2, #T_926be_row605_col1, #T_926be_row605_col2 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_926be_row0_col2, #T_926be_row1_col2, #T_926be_row2_col2, #T_926be_row6_col2, #T_926be_row128_col2, #T_926be_row129_col2, #T_926be_row130_col2, #T_926be_row131_col2, #T_926be_row384_col1, #T_926be_row388_col1, #T_926be_row389_col1, #T_926be_row390_col1 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_926be_row3_col1, #T_926be_row4_col1, #T_926be_row5_col1, #T_926be_row7_col1, #T_926be_row24_col1, #T_926be_row25_col1, #T_926be_row26_col1, #T_926be_row27_col1, #T_926be_row40_col1, #T_926be_row41_col1, #T_926be_row42_col1, #T_926be_row43_col1, #T_926be_row152_col1, #T_926be_row155_col1, #T_926be_row156_col1, #T_926be_row158_col1, #T_926be_row256_col1, #T_926be_row257_col1, #T_926be_row258_col1, #T_926be_row259_col1, #T_926be_row328_col2, #T_926be_row329_col2, #T_926be_row330_col2, #T_926be_row331_col2, #T_926be_row432_col1, #T_926be_row433_col2, #T_926be_row434_col2, #T_926be_row435_col1, #T_926be_row436_col2, #T_926be_row437_col2, #T_926be_row438_col1, #T_926be_row439_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_926be_row3_col2, #T_926be_row4_col2, #T_926be_row5_col2, #T_926be_row7_col2, #T_926be_row509_col1, #T_926be_row511_col1, #T_926be_row513_col1, #T_926be_row515_col1 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_926be_row8_col1, #T_926be_row9_col1, #T_926be_row10_col1, #T_926be_row13_col1, #T_926be_row188_col2, #T_926be_row189_col2, #T_926be_row190_col2, #T_926be_row191_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_926be_row8_col2, #T_926be_row9_col2, #T_926be_row10_col2, #T_926be_row13_col2, #T_926be_row66_col2, #T_926be_row67_col2, #T_926be_row70_col2, #T_926be_row71_col2, #T_926be_row92_col2, #T_926be_row93_col2, #T_926be_row94_col2, #T_926be_row95_col2 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_926be_row11_col1, #T_926be_row12_col1, #T_926be_row14_col1, #T_926be_row15_col1, #T_926be_row56_col1, #T_926be_row57_col1, #T_926be_row58_col1, #T_926be_row59_col1, #T_926be_row60_col1, #T_926be_row61_col1, #T_926be_row62_col1, #T_926be_row63_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_926be_row11_col2, #T_926be_row12_col2, #T_926be_row14_col2, #T_926be_row15_col2, #T_926be_row124_col2, #T_926be_row125_col2, #T_926be_row126_col2, #T_926be_row127_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_926be_row16_col1, #T_926be_row20_col1, #T_926be_row22_col1, #T_926be_row23_col1, #T_926be_row28_col1, #T_926be_row29_col1, #T_926be_row30_col1, #T_926be_row31_col1, #T_926be_row44_col1, #T_926be_row45_col1, #T_926be_row47_col1, #T_926be_row49_col1, #T_926be_row50_col1, #T_926be_row51_col1, #T_926be_row53_col1, #T_926be_row55_col1, #T_926be_row112_col2, #T_926be_row116_col2, #T_926be_row117_col2, #T_926be_row118_col2, #T_926be_row153_col2, #T_926be_row154_col2, #T_926be_row157_col2, #T_926be_row159_col2 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_926be_row16_col2, #T_926be_row20_col2, #T_926be_row22_col2, #T_926be_row23_col2, #T_926be_row134_col1, #T_926be_row135_col1, #T_926be_row137_col1, #T_926be_row139_col1 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_926be_row17_col1, #T_926be_row18_col1, #T_926be_row19_col1, #T_926be_row21_col1, #T_926be_row160_col2, #T_926be_row161_col2, #T_926be_row162_col2, #T_926be_row163_col2, #T_926be_row204_col2, #T_926be_row206_col2, #T_926be_row207_col2, #T_926be_row211_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_926be_row17_col2, #T_926be_row18_col2, #T_926be_row19_col2, #T_926be_row21_col2, #T_926be_row64_col2, #T_926be_row65_col2, #T_926be_row68_col2, #T_926be_row69_col2, #T_926be_row510_col2, #T_926be_row512_col2, #T_926be_row514_col2, #T_926be_row516_col2 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_926be_row24_col2, #T_926be_row25_col2, #T_926be_row26_col2, #T_926be_row27_col2, #T_926be_row32_col1, #T_926be_row34_col1, #T_926be_row36_col1, #T_926be_row38_col1, #T_926be_row76_col1, #T_926be_row84_col1, #T_926be_row86_col1, #T_926be_row87_col1, #T_926be_row96_col1, #T_926be_row97_col1, #T_926be_row98_col1, #T_926be_row99_col1, #T_926be_row313_col2, #T_926be_row314_col2, #T_926be_row318_col2, #T_926be_row319_col2, #T_926be_row472_col2, #T_926be_row475_col2, #T_926be_row476_col2, #T_926be_row477_col2 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_926be_row28_col2, #T_926be_row29_col2, #T_926be_row30_col2, #T_926be_row31_col2, #T_926be_row104_col2, #T_926be_row105_col2, #T_926be_row106_col2, #T_926be_row107_col2 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_926be_row32_col2, #T_926be_row34_col2, #T_926be_row36_col2, #T_926be_row38_col2, #T_926be_row134_col2, #T_926be_row135_col2, #T_926be_row137_col2, #T_926be_row139_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_926be_row33_col1, #T_926be_row35_col1, #T_926be_row37_col1, #T_926be_row39_col1, #T_926be_row66_col1, #T_926be_row67_col1, #T_926be_row70_col1, #T_926be_row71_col1, #T_926be_row108_col1, #T_926be_row109_col1, #T_926be_row110_col1, #T_926be_row111_col1, #T_926be_row140_col1, #T_926be_row141_col1, #T_926be_row142_col1, #T_926be_row143_col1, #T_926be_row384_col2, #T_926be_row388_col2, #T_926be_row389_col2, #T_926be_row390_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_926be_row33_col2, #T_926be_row35_col2, #T_926be_row37_col2, #T_926be_row39_col2, #T_926be_row46_col2, #T_926be_row48_col2, #T_926be_row52_col2, #T_926be_row54_col2, #T_926be_row172_col2, #T_926be_row173_col2, #T_926be_row174_col2, #T_926be_row175_col2, #T_926be_row448_col1, #T_926be_row449_col1, #T_926be_row450_col1, #T_926be_row451_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_926be_row40_col2, #T_926be_row41_col2, #T_926be_row42_col2, #T_926be_row43_col2, #T_926be_row333_col1, #T_926be_row336_col1, #T_926be_row337_col1, #T_926be_row339_col1, #T_926be_row611_col1, #T_926be_row613_col1, #T_926be_row620_col1, #T_926be_row629_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_926be_row44_col2, #T_926be_row45_col2, #T_926be_row47_col2, #T_926be_row49_col2, #T_926be_row50_col2, #T_926be_row51_col2, #T_926be_row53_col2, #T_926be_row55_col2, #T_926be_row108_col2, #T_926be_row109_col2, #T_926be_row110_col2, #T_926be_row111_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_926be_row46_col1, #T_926be_row48_col1, #T_926be_row52_col1, #T_926be_row54_col1, #T_926be_row92_col1, #T_926be_row93_col1, #T_926be_row94_col1, #T_926be_row95_col1, #T_926be_row104_col1, #T_926be_row105_col1, #T_926be_row106_col1, #T_926be_row107_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_926be_row56_col2, #T_926be_row57_col2, #T_926be_row58_col2, #T_926be_row59_col2, #T_926be_row473_col1, #T_926be_row474_col1, #T_926be_row478_col1, #T_926be_row479_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_926be_row60_col2, #T_926be_row61_col2, #T_926be_row62_col2, #T_926be_row63_col2 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_926be_row64_col1, #T_926be_row65_col1, #T_926be_row68_col1, #T_926be_row69_col1, #T_926be_row256_col2, #T_926be_row257_col2, #T_926be_row258_col2, #T_926be_row259_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_926be_row72_col1, #T_926be_row73_col1, #T_926be_row74_col1, #T_926be_row78_col1, #T_926be_row79_col1, #T_926be_row81_col1, #T_926be_row83_c
# Sharpe Test: media=0.266 | max=2.433
# Degradacion media: +0.7% | 600/636 configs mejoran

# %%
import glob
figuras = sorted(glob.glob(os.path.join(DIR_FIGURES, 'wf_*.png')))
print(f'Figuras en {DIR_FIGURES}:')
for f in figuras:
    print(f'  {os.path.basename(f):55s} {os.path.getsize(f)/1024:6.1f} KB')
# Out:
# Figuras en c:\Users\marce\Desktop\UNIR\TFM\Proyecto\git\hybrid-momentum-anomaly-detection\results\figures:
#   wf_01_equity_curve_winner_daily.png                      140.9 KB
#   wf_02_sharpe_scatter.png                                 132.3 KB
#   wf_03_degradation_bar.png                                110.6 KB
#   wf_04_hyperparameter_distribution_oos.png                157.9 KB
#   wf_05_sharpe_distribution_grid.png                        68.0 KB
#   wf_06_oos_parameter_sensitivity_top10pct.png             741.3 KB
